# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [10000, 30000, 50000, 100000, 300000, 500000]
selection_sort = [0.061788, 0.513556, 1.5255, 5.79208, 52.7115, 140.803]
insertion_sort = [0.080077, 0.699052, 1.9577, 7.7151, 72.3781, 183.361]
bubble_sort = [0.284325, 2.69876, 7.56983, 29.585, 269.217, 718.749]
shaker_sort = [0.302891, 2.7869, 7.4226, 30.5067, 276.025, 762.743]
shell_sort = [0.000418, 0.001782, 0.00428, 0.008626, 0.023653, 0.030035]
heap_sort = [0.001538, 0.00612, 0.011387, 0.025298, 0.072835, 0.096763]
merge_sort = [0.042207, 0.120794, 0.196447, 0.3686, 1.17752, 1.92498]
quick_sort = [0.000235, 0.000487, 0.001533, 0.001957, 0.00754, 0.009649]
counting_sort = [0.002692,	0.002865, 0.00313, 0.00323, 0.004803, 0.006733]
radix_sort = [0.000538, 0.001918, 0.003264, 0.006939, 0.023631, 0.036629]
flash_sort = [0.000205, 0.0006, 0.000979, 0.002167, 0.010219, 0.009729] 

plt.figure(figsize=(8, 15))
ttl = plt.title("Reversed Input", y=1.02, fontsize=20, weight="bold")
plt.xlabel("Input size", fontsize=20, weight="bold")
plt.ylabel("Run time in seconds", fontsize=20, weight="bold")


# plt.plot(x, selection_sort, label="Selection Sort", marker="s",linewidth=4, markersize=10)
# plt.plot(x, insertion_sort, label="Insertion Sort", marker="s", linewidth=4, markersize=10)
# plt.plot(x, bubble_sort, label="Bubble Sort", marker="s", linewidth=4, markersize=10)
# plt.plot(x, shaker_sort, label="Shaker Sort", marker="s", linewidth=4, markersize=10)
# plt.plot(x, shell_sort, label="Shell Sort", marker="s", linewidth=4, markersize=10)
# plt.plot(x, heap_sort, label="Heap Sort", marker="s", linewidth=4, markersize=10)
# plt.plot(x, merge_sort, label="Merge Sort", marker="s", linewidth=4, markersize=10)
# plt.plot(x, quick_sort, label="Quick Sort", marker="s", linewidth=4, markersize=10)
plt.plot(x, counting_sort, label="Counting Sort", marker="s", linewidth=4, markersize=10)
plt.plot(x, radix_sort, label="Radix Sort", marker="s", linewidth=4, markersize=10)
plt.plot(x, flash_sort, label="Flash Sort", marker="s", linewidth=4, markersize=10)


legend = plt.legend(loc="center left", bbox_to_anchor=(1, 0.5), fontsize=15)
plt.subplots_adjust(right=2.5)
plt.xticks(x, x, fontsize=13)
plt.yticks(fontsize=13)
plt.grid()
plt.show()
